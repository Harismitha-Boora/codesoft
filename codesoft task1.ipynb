# %% [markdown]
# # import require modules

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split

# %% [markdown]
# # importing dataset

# %%
df=pd.read_csv("titanic_dataset(1).csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1   38      1
# 2                               Heikkinen, Miss. Laina    1   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1   35      1
# 4                             Allen, Mr. William Henry    0   35      0
# ..                                                 ...  ...  ...    ...
# ...

# %% [markdown]
# # splitting the data into independent and dependent variables

# %%
x=df[["PassengerId","Pclass","Sex","Age","SibSp","Parch","Fare"]]
y=df[["Survived"]]

# %% [markdown]
# # splitting the dataframe into train and test

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=450)

# %%
test_x
# Out:
#      PassengerId  Pclass  Sex  Age  SibSp  Parch  Fare
# 499          500       3    0   24      0      0     8
# 335          336       3    0    0      0      0     8
# 778          779       3    0    0      0      0     8
# 314          315       2    0   43      1      1    26
# 863          864       3    1    0      8      2    70
# ..           ...     ...  ...  ...    ...    ...   ...
# 829          830       1    1   62      0      0    80
# 644          645       3    1    1      2      1    19
# 708          709       1    1   22      0      0   152
# 250          251       3    0    0      0      0     7
# 690          691       1    0   31      1      0    57
#
# [450 rows x 7 columns]

# %%
test_y
# Out:
#      Survived
# 499         0
# 335         0
# 778         0
# 314         0
# 863         0
# ..        ...
# 829         1
# 644         1
# 708         1
# 250         0
# 690         1
#
# [450 rows x 1 columns]

# %% [markdown]
# # Training tha model

# %%
l=LogisticRegression()
l.fit(train_x,train_y)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Predicting the model

# %%
l.predict([[519,2,1,36,1,0,26]])
# Out:
# array([1], dtype=int64)

# %%
l.predict([[434,3,0,17,0,0,7]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Accuracy of the model

# %%
l.score(train_x,train_y)
# Out:
# 0.8049886621315193
