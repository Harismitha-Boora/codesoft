# %% [markdown]
# # importting the require modules

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# # importting the dataset

# %%
df=pd.read_csv("creditcard.csv")

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# # splitting the dataframe Independent and dependent variables

# %%
x=df[["Time","V1","V2","V3","V4","V5","V6","V7","V8","V9","V10","V11","V12","V13","V14","V15","V16","V17","V18","V19","V20","V21","V22","V23","V24","V25","V26","V27","V28","Amount"]]
y=df[["Class"]]

# %% [markdown]
# # splitting the into train and test

# %%
train_x,test_x,train_y,test_y=train_test_split(x,y,test_size=142403,random_state=0)

# %%
train_x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 26400    34047.0  0.747783 -0.830659 -0.104736 -0.501762 -0.828840 -0.495666
# 269414  163651.0 -2.233817  2.227199  0.687360 -0.939483  0.281006  0.562074
# 75463    56082.0  1.260499  0.186565  0.495507  0.629737 -0.561331 -1.015483
# 99307    67058.0  1.192812  0.188461  0.142047  0.456979 -0.034893 -0.105651
# 212267  138791.0 -2.024038 -2.546721 -1.077908 -1.996123 -1.845373  3.065465
# ...          ...       ...       ...       ...       ...       ...       ...
# 211543  138459.0 -1.321976  1.138686 -0.940861  0.154160  0.109802 -0.538822
# 86293    61167.0 -0.627810  0.918729  1.478453  0.213171  0.933695  1.261486
# 122579   76616.0  1.512602 -0.949435 -0.219062 -1.638850 -0.856348 -0.465996
# 152315   97253.0  1.798863 -1.699791 -0.142182 -0.619533 -1.570248  0.083268
# 117952   74887.0 -0.589400  0.747828  1.784781  0.899612  0.257067 -0.001301
#
# ...

# %%
train_y
# Out:
#         Class
# 26400       0
# 269414      0
# 75463       0
# 99307       0
# 212267      0
# ...       ...
# 211543      0
# 86293       0
# 122579      0
# 152315      0
# 117952      0
#
# [142404 rows x 1 columns]

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Training the model

# %%
l=LogisticRegression()
l.fit(train_x,train_y)
# Out:
# LogisticRegression()

# %% [markdown]
# # predicting the model

# %%
l.predict([[172742,2.050734338,-0.364009836,-2.542842686,-0.729357246,2.388455136,3.318014827,-0.479137991,0.791558699,0.403373926,0.093232296,0.004390637,0.390166352,-0.212555238,0.495543631,0.47263305,-0.171594984,-0.368260802,-0.976571678,0.022869491,-0.154977953,-0.29336299,-0.834801883,0.381740403,0.698179491,-0.264798456,0.219274981,-0.05213116,-0.066940016,0.89]])
# Out:
# array([0], dtype=int64)

# %%
l.predict([[172273,-0.765413952,1.343887362,-0.306100795,-0.645545109,-0.067357686,-1.172195543,0.516072576,0.342927196,0.368226875,0.014743193,-1.202725651,-0.36131393,-1.246508535,0.554692314,-0.219734696,-0.009805464,-0.126413721,-0.670763737,-0.210449491,0.010650537,-0.289751901,-0.709882031,0.173594272,-0.064594074,-0.420300291,0.15989535,0.330875406,0.150175049,1.98]])
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Accuracy of the model

# %%
l.score(train_x,train_y)
# Out:
# 0.9989255919777534
